# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt

from labeling import triple_barrier

# %%
ohlcv = pd.read_csv('~/crypto_data/exchange_data/combined/BTCSPOT_3600.csv', index_col=0, parse_dates=True)

# %%
log_ret = np.log(ohlcv['close'].shift(freq='4H')) - np.log(ohlcv['close'])
rolling_std = log_ret.rolling('1D').std()
rolling_std.plot()
# Out:
# <AxesSubplot:>
